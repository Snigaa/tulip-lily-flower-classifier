# %%
# !pip install tensorflow matplotlib numpy pillow

# %% [markdown]
# ## importing libraries

# %%
# !pip install tensorflow

# %%
# !pip install tensorflow matplotlib numpy pillow --quiet --no-warn-conflicts

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# %% [raw]
# import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [raw]
# import os

# %%
import zipfile

# %%
import shutil

# %%
import requests

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
print("TensorFlow ver:", tf.__version__)
# Out:
# TensorFlow ver: 2.20.0

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\rajde

# %%
print(os.listdir())
# Out:
# ['.anaconda', '.cache', '.conda', '.condarc', '.config', '.continuum', '.fastai', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.keras', '.m2', '.matplotlib', '.ms-ad', '.ollama', '.vscode', '3D Objects', 'anaconda3', 'anaconda_projects', 'ANNLAB.py', 'AppData', 'Application Data', 'BullseyeCoverageError.txt', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'Dropbox', 'Favorites', 'flowers_dataset', 'Links', 'll', 'Local Settings', 'ml', 'ml.ipynb', 'Music', 'My Documents', 'NetHood', 'New folder', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{80cbdeb2-de75-11ef-a5c6-aac6d0c0bbba}.TM.blf', 'NTUSER.DAT{80cbdeb2-de75-11ef-a5c6-aac6d0c0bbba}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{80cbdeb2-de75-11ef-a5c6-aac6d0c0bbba}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'PERSONAL', 'practical.c', 'practical.exe', 'PrintHood', 'pylab.ipynb', 'python lab.ipynb', 'Recent', 'Saved Games', 'Searches', 'SendTo',
# ...

# %%
import os

os.makedirs("flowers_dataset/train/lilies", exist_ok=True)
os.makedirs("flowers_dataset/train/tulips", exist_ok=True)
os.makedirs("flowers_dataset/test/lilies", exist_ok=True)
os.makedirs("flowers_dataset/test/tulips", exist_ok=True)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\rajde

# %%
print(os.listdir())
# Out:
# ['.anaconda', '.cache', '.conda', '.condarc', '.config', '.continuum', '.fastai', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.keras', '.m2', '.matplotlib', '.ms-ad', '.ollama', '.vscode', '3D Objects', 'anaconda3', 'anaconda_projects', 'ANNLAB.py', 'AppData', 'Application Data', 'BullseyeCoverageError.txt', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'Dropbox', 'Favorites', 'flowers_dataset', 'Links', 'll', 'Local Settings', 'ml', 'ml.ipynb', 'Music', 'My Documents', 'NetHood', 'New folder', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{80cbdeb2-de75-11ef-a5c6-aac6d0c0bbba}.TM.blf', 'NTUSER.DAT{80cbdeb2-de75-11ef-a5c6-aac6d0c0bbba}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{80cbdeb2-de75-11ef-a5c6-aac6d0c0bbba}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'PERSONAL', 'practical.c', 'practical.exe', 'PrintHood', 'pylab.ipynb', 'python lab.ipynb', 'Recent', 'Saved Games', 'Searches', 'SendTo',
# ...

# %%
import os
print(os.listdir("flowers_dataset"))
# Out:
# ['test', 'train']

# %%
print(os.listdir("flowers_dataset/train"))
# Out:
# ['lilies', 'tulips']

# %%
print(os.listdir("flowers_dataset/train/lilies"))
# Out:
# ['1.jpg', '10.jpg', '11.jpg', '12.jpg', '13.jpg', '14.jpg', '15.jpg', '16.jpg', '17.jpg', '18.jpg', '19.jpg', '2.jpg', '20.jpg', '3.jpg', '4.jpg', '5.jpg', '6.jpg', '7.jpg', '8.jpg', '9.jpg']

# %%
from PIL import Image
import matplotlib.pyplot as plt
import os


img = Image.open(r"C:\Users\rajde\flowers_dataset\train\lilies\2.jpg")
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 2866.5, 3822.5, -0.5)

# %%
from PIL import Image
import matplotlib.pyplot as plt
import os

# %%
folder = "flowers_dataset/train/lilies"
images = os.listdir(folder)

plt.figure(figsize=(12,6))

for i in range(min(7, len(images))):
    img = Image.open(os.path.join(folder, images[i]))
    plt.subplot(1, 7, i+1)
    plt.imshow(img)
    plt.axis("off")

plt.show()

# %%
folder = "flowers_dataset/train/lilies"
img_name = os.listdir(folder)[0]

img = Image.open(os.path.join(folder, img_name))
img = img.resize((100, 100))   # resize image

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 99.5, 99.5, -0.5)

# %%
import numpy as np

# %%
img_array = np.array(img)

# %%
print(img_array)
# Out:
# [[[19 14 20]
#   [19 14 19]
#   [19 14 19]
#   ...
#   [14 14 16]
#   [14 14 16]
#   [14 14 16]]
#
#  [[17 13 18]
#   [16 14 17]
#   [18 13 17]
#   ...
#   [14 13 16]
#   [14 14 16]
#   [14 14 16]]
#
#  [[17 13 16]
#   [16 13 17]
#   [17 13 17]
#   ...
#   [14 14 16]
#   [14 13 16]
#   [14 14 16]]
#
#  ...
#
#  [[22 17 23]
#   [22 17 23]
#   [22 17 23]
#   ...
#   [16 14 17]
#   [16 15 17]
#   [16 14 17]]
#
#  [[23 17 23]
#   [22 17 23]
#   [22 17 23]
#   ...
#   [15 14 17]
#   [15 14 17]
#   [15 15 18]]
#
#  [[22 17 23]
#   [22 17 23]
#   [22 17 23]
#   ...
#   [21 23 18]
#   [18 18 18]
#   [16 15 17]]]

# %%
print(img_array.shape)
# Out:
# (100, 100, 3)

# %%
folder = "flowers_dataset/train/tulips"
images = os.listdir(folder)

plt.figure(figsize=(12,6))

for i in range(min(7, len(images))):
    img = Image.open(os.path.join(folder, images[i]))
    plt.subplot(1, 7, i+1)
    plt.imshow(img)
    plt.axis("off")

plt.show()

# %%
train_datagen.flow_from_directory(
    "flowers_dataset/train",
    target_size=(100, 100),
    batch_size=8,
    class_mode="binary"
)
# Out:
# Found 40 images belonging to 2 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), 
                           activation='relu', 
                           input_shape=(100,100,3),
                          ),
    
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)                    │ (None, 98, 98, 16)          │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 49, 49, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 47, 47, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 23, 23, 32)          │               0 │
# ...

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    "flowers_dataset/train",
    target_size=(224, 224),   
    batch_size=8,
    class_mode="binary"
)

test_data = test_datagen.flow_from_directory(
    "flowers_dataset/test",
    target_size=(224, 224),   
    batch_size=8,
    class_mode="binary"
)
# Out:
# Found 40 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.

# %%
base_model = MobileNetV2(
    input_shape=(224,224,3),
    include_top=False,
    weights="imagenet"
)

base_model.trainable = False  # VERY IMPORTANT

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(32, activation="relu")(x)
output = Dense(1, activation="sigmoid")(x)

model = Model(inputs=base_model.input, outputs=output)

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)    │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv1 (Conv2D)                │ (None, 112, 112, 32)      │             864 │ input_layer_5[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bn_Conv1 (BatchNormalization) │ (None, 112, 112, 32)      │             128 │ Conv1[0][0]                │
# ...

# %%
history = model.fit(
    train_data,
    epochs=5,
    validation_data=test_data
)
# Out:
# Epoch 1/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 54s 11s/step - accuracy: 0.7500 - loss: 0.5100 - val_accuracy: 1.0000 - val_loss: 0.3623
# Epoch 2/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 7s/step - accuracy: 1.0000 - loss: 0.1884 - val_accuracy: 1.0000 - val_loss: 0.2249
# Epoch 3/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 7s/step - accuracy: 1.0000 - loss: 0.0822 - val_accuracy: 0.9375 - val_loss: 0.1752
# Epoch 4/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 7s/step - accuracy: 1.0000 - loss: 0.0447 - val_accuracy: 0.9375 - val_loss: 0.1515
# Epoch 5/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 7s/step - accuracy: 1.0000 - loss: 0.0167 - val_accuracy: 0.9375 - val_loss: 0.1511

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.show()

# %%
model.save("tuliplilly.keras")

# %%
from tensorflow.keras.models import load_model

model = load_model("tuliplilly.keras")
# Out:
# C:\Users\rajde\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 6 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt


image_path = r"C:\Users\rajde\flowers_dataset\test\lilies\L24.jpg"


img = load_img(image_path, target_size=(224,224))
plt.imshow(img)
plt.axis("off")
plt.show()


img_array = img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Predict
prediction = model.predict(img_array)

# Result
if prediction[0][0] > 0.5:
    print("🌷 This is a TULIP")
else:
    print("🌸 This is a LILY")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 🌸 This is a LILY

# %%
from ipywidgets import FileUpload
from IPython.display import display

upload = FileUpload(accept='image/*', multiple=False)
display(upload)
# Out:
# FileUpload(value=(), accept='image/*', description='Upload')

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import io

# ✅ Correct way to read uploaded image
uploaded_file = upload.value[0]          # first (and only) file
image_bytes = uploaded_file['content']   # raw image bytes

# Open image
img = Image.open(io.BytesIO(image_bytes)).resize((224,224))

# Show image
plt.imshow(img)
plt.axis("off")
plt.show()

# Prepare for model
img_array = np.array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)[0][0]

# Convert to confidence
if prediction > 0.5:
    label = "🌷 TULIP"
    confidence = prediction * 100
else:
    label = "🌸 LILY"
    confidence = (1 - prediction) * 100

print(f"Prediction: {label}")
print(f"Confidence: {confidence:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Prediction: 🌸 LILY
# Confidence: 91.30%
